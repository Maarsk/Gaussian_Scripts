# %%
from scm.plams import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from scm.plams import *
#
# ModuleNotFoundError: No module named 'scm'

# %%
rkf = KFFile('\Input\ADF\socme-tda_SCM-DCM_Fac_S1.rkf')
exc = rkf.read_section('Excitations')

# Example: get coefficients for excitation 3
coeffs = exc['Coeff(3)']   # returns list of floats
orbs   = exc['Orbitals(3)']  # list of (occ, virt) pairs
